# %% [markdown]
# Najpierw laczone range czyli
#
# Futures Premarket Range: 8:00 – 9:00

# %% [markdown]
# Open range: 9:00 – 9:05

# %% [markdown]
# Opening Range: 9:00-10:00

# %% [markdown]
# RTH Range: 9:00 – 15:00

# %% [markdown]
# Averages:

# %% [markdown]
# FuturesPremarketRange     42.544643

# %% [markdown]
# OpenRange                 32.029762

# %% [markdown]
# OpeningRange              76.663690

# %% [markdown]
# RTHRange                 154.398810

# %% [markdown]
# dtype: float64

# %% [markdown]
# Medians:

# %% [markdown]
# FuturesPremarketRange     38.0

# %% [markdown]
# OpenRange                 29.0

# %% [markdown]
# OpeningRange              69.5

# %% [markdown]
# RTHRange                 142.0

# %% [markdown]
# dtype: float64

# %% [markdown]
# Ponizej diagram I correlation Matrix

# %% [markdown]
# ![image](data:image/png;base64,...)

# %% [markdown]
# ![image](data:image/png;base64,...)

# %% [markdown]
# Ponizej dane oddzielne, dla kazdego range’a wyekstrahowane bardziej oddzielnie tzn.

# %% [markdown]
# Futures Premarket Range: 8:00 – 8:10

# %% [markdown]
# Open range: 9:00 – 9:05

# %% [markdown]
# Opening Range: 9:05-10:00

# %% [markdown]
# RTH Range: 10:00 – 14:00

# %% [markdown]
# Averages:

# %% [markdown]
# FuturesPremarketRange     26.951705

# %% [markdown]
# OpenRange                 32.806818

# %% [markdown]
# OpeningRange              72.321023

# %% [markdown]
# RTHRange                 115.948864

# %% [markdown]
# dtype: float64

# %% [markdown]
# Medians:

# %% [markdown]
# FuturesPremarketRange     24.0

# %% [markdown]
# OpenRange                 30.5

# %% [markdown]
# OpeningRange              66.0

# %% [markdown]
# RTHRange                 102.0

# %% [markdown]
# dtype: float64

# %% [markdown]
# ![image](data:image/png;base64,...)

# %% [markdown]
# ![image](data:image/png;base64,...)

# %% [markdown]
# Przede mna duzy research:

# %% [markdown]
# TOP 3-10% Opening Range (9:05-10:00)

# %% [markdown]
# Analogicznie reszta, ale zaczne od ww

# %% [markdown]
# Przez ostatnie 1.5 roku~ mamy 39 case’ow gdzie Opening Range jest powyzej 120

# %% [markdown]
# Percentages for OpeningRange above 120:

# %% [markdown]
# (120, 140]    4.545455

# %% [markdown]
# (140, 160]    3.409091

# %% [markdown]
# (160, 200]    2.272727

# %% [markdown]
# (200, 300]    0.852273

# %% [markdown]
# Chyba na razie research reczny tych chociaz 10-15 przypadkow:

# %% [markdown]
# 25.04.22 – OR: 168 ///

# %% [markdown]
# Tutaj szybka akcja, cofka do low OR, i potem

# %% [markdown]
# jazda

# %% [markdown]
# w gore – 90% zrobione dosc szybko a ponad 1:1 (i wiecej) do wieczora

# %% [markdown]
# ![image](data:image/png;base64,...)

# %% [markdown]
# 27.04.22 – OR: 213

# %% [markdown]
# Tutaj w zasadzie gorna banda stanowila miejsce na retesty, dolu nie zobaczylismy w zasadzie, od gory ostatecznie poszedl uptrend pozniejszy, ale idk czy bym to zagral finalnie

# %% [markdown]
# @@”LUKA” Box dol zaliczona 6.05 dopiero -ale caly czas byla w grze – zaliczony potem retrace 50% boxa, wiec moglbym to grac gdybym wiedzial

# %% [markdown]
# ![image](data:image/png;base64,...)

# %% [markdown]
# 28.04.22 – OR: 144

# %% [markdown]
# Tutaj pelne spektrum tego dnia, rozegranie range’a w obie strony – z tym, ze tutaj tez SL musialby byc adekwatnie duzy, no bo mocno tam wialo – nadbitka byla nawet na okolo 70p na dole (alternatywa po prostu pickup po powrocie)

# %% [markdown]
# ![image](data:image/png;base64,...)

# %% [markdown]
# 2.05.22 – OR: 236

# %% [markdown]
# Tutaj byla fajna reakcja jeszcze tego samego dnia, natomiast okolo 80-85% siadlo i cofnelo – tutaj potem borowalo przy gornej krawedzi az w koncu poszlo w gore jeszcze bardziej – typowo zachowanie lukowe tbh. Ogolnie tutaj gesto sa ogromne OR, taki wolumen wtedy szedl, dzien pozniej tez sie zdarzylo tak

# %% [markdown]
# @BOX zaliczony 6.05 – ciekawe czy bedzie odbitka

# %% [markdown]
# ![image](data:image/png;base64,...)

# %% [markdown]
# 3.05.22 – OR: 123 (dosc maly w porownaniu z wczoraj)

# %% [markdown]
# Co prawda dopiero nastepnego dnia, ale setup siadl.

# %% [markdown]
# Chociaz i juz na poczatku byla nadbitka i mozna bylo grac na powrot range’a

# %% [markdown]
# ![image](data:image/png;base64,...)

# %% [markdown]
# 6.05 – OR: 144

# %% [markdown]
# Tutaj caly czas gral ten range z 2.05 i w sumie juz zblizamy sie do niego,

# %% [markdown]
# Natomiast byly retrace’y do 50% Ora tego dzisiejszego co najmniej 2,

# %% [markdown]
# Pozniej dol boxa stal sie miejscem do brania trejdow

# %% [markdown]
# ![image](data:image/png;base64,...)

# %% [markdown]
# 12.05 – OR:162

# %% [markdown]
# Bylo dotkniecie dolnej bandy a potem zaliczona gora (tutaj bez wiekszych nadbitek),

# %% [markdown]
# Potem gorna banda stala sie baza do ruchow w gore.

# %% [markdown]
# ![image](data:image/png;base64,...)

# %% [markdown]
# 19.05 - OR: 166

# %% [markdown]
# Zaliczona nadbitka a potem pieknie zaliczona gora, i gorna banda znowu stala sie baza – DZIEN POZNIEJ BYL TAM SWIETNY SETUP!

# %% [markdown]
# ![image](data:image/png;base64,...)

# %% [markdown]
# 14.06 – OR: 125

# %% [markdown]
# Tutaj pewnie siadlby SL, bo poszlismy pod dolna i dolna byla baza do odbitki – ale byly tutaj okazje do zgrywki nawet pozniej, gdy juz weszlismy do boxa i zamiast walnac gore jeszcze raz retrace do dolnej i potem dopiero gora

# %% [markdown]
# ![image](data:image/png;base64,...)

# %% [markdown]
# 16.06.22 – OR: 252punkty /// powrot do gory 21.06 – reakcja

# %% [markdown]
# Dolna banda byla strefa bounce’ow i przez kilka dni szlo tam urwac troche skalpow

# %% [markdown]
# Gdy poszlo w koncu na gorna bande, tam nastapil bounce i znowu spadlo do samego dolu setupu

# %% [markdown]
# ![image](data:image/png;base64,...)

# %% [markdown]
# 23.06 – OR: 172

# %% [markdown]
# Fajnie rozegrane, nadbitka i potem zaliczony dol, nastepnego dnia w boxie powrot do dolu i gora

# %% [markdown]
# ![image](data:image/png;base64,...)

# %% [markdown]
# 27.06.22 – OR: 142

# %% [markdown]
# Pieknie rozegrane, szybka nadbitka i zjazd w dol

# %% [markdown]
# ![image](data:image/png;base64,...)

# %% [markdown]
# 28.06.22 – OR: 145

# %% [markdown]
# Tutaj tbh nie za wiele sie dzialo, ale tez tak naprawde ten OR sie otworzyl w range’u poprzedniego

# %% [markdown]
# ![image](data:image/png;base64,...)

# %% [markdown]
# 1.07.22 – OR: 150

# %% [markdown]
# Tutaj bardziej niz nadbitka byla strefa nad i high stalo sie range’m

# %% [markdown]
# ![image](data:image/png;base64,...)

# %% [markdown]
# 4.07.22 – OR: 131

# %% [markdown]
# Tutaj nadbitka solidna, 50p+, potem cofka ale do 50-60%

# %% [markdown]
# ![image](data:image/png;base64,...)

# %% [markdown]
# 6.07.22 – OR: 122

# %% [markdown]
# Nadbitka, potem w koncu zrobiona gorna banda, chociaz najpierw 50%, potem 90%, ale zrobione

# %% [markdown]
# ![image](data:image/png;base64,...)

# %% [markdown]
# Tak czy inaczej wyglada to fajnie do przetestowania – tych setupow nie ma duzo, aczkolwiek jesli zobaczymy rowniez te top pare procent w innych strefach, to bedzie ich wiecej. Wydaja sie git.
